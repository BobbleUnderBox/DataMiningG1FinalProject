# %% [markdown]
# # 環境設置與資料載入

# %%
import sys
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# 設定中文字體
plt.rcParams['font.family'] = ['Microsoft JhengHei', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False

# 添加專案根目錄到 Python 路徑
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# 匯入資料載入系統
from src.data_loader import load_data, DataLoader, ConfigLoader

# 載入配置
config = ConfigLoader.load_config(project_root / "config.yaml")
loader = DataLoader(config)

print("✅ 環境初始化完成")
# Out:
# 2026-05-24 16:34:36,469 - src.data_loader - INFO - ✅ 設定檔已載入: c:\Users\fromn\OneDrive\Desktop\dataMiningCourse\dataMining\config.yaml
# ✅ 環境初始化完成

# %%
# 載入原始資料（若本地無資料則會自動嘗試從 Kaggle 下載）
df = load_data()
print(f"原始資料形狀: {df.shape}")
display(df.head())

# 基本統計摘要
print("\n數值欄位摘要:")
display(df.describe())

print("\n所有欄位摘要:")
display(df.describe(include='all').T)
# Out:
# 2026-05-24 16:34:39,762 - src.data_loader - INFO - ✅ 設定檔已載入: c:\Users\fromn\OneDrive\Desktop\dataMiningCourse\dataMining\config.yaml
# 2026-05-24 16:34:39,764 - src.data_loader - INFO - ✅ 優先使用專案本地資料: c:\Users\fromn\OneDrive\Desktop\dataMiningCourse\dataMining\data\raw\Buy_Now_Pay_Later_BNPL_CreditRisk_Dataset.csv
# 2026-05-24 16:34:39,766 - src.data_loader - INFO - 📖 讀取資料檔案: c:\Users\fromn\OneDrive\Desktop\dataMiningCourse\dataMining\data\raw\Buy_Now_Pay_Later_BNPL_CreditRisk_Dataset.csv
# 2026-05-24 16:34:39,835 - src.data_loader - INFO - ✅ 資料已載入 | 形狀: (10345, 17)
# 原始資料形狀: (10345, 17)
#    user_id  age employment_type  monthly_income  credit_score  \
# 0        1   56        Salaried        68529.50           552
# 1        2   19         Student         7247.85           300
# 2        3   20   Self-Employed        41582.26           471
# 3        4   21        Salaried        14423.46           300
# 4        5   43        Salaried        42845.50           512
#
#    purchase_amount product_category  bnpl_installments  repayment_delay_days  \
# 0          5000.00      Electronics                 12                    13
# 1          1073.23          Fashion                 12                    13
# 2          5000.00      Electronics                  3                    19
# 3          4076.83           Sports                  6                    18
# 4          5000.00      Electronics                  9                     0
#
#    missed_payments  default_flag  app_usage_frequency   location  \
# 0                1             0                 8.49  Australia
# 1                1             0                 3.09        USA
# 2                2             0                 3.33  Australia
# 3                5             1                 5.86    Germany
# 4                0             0                 7.36      India
#
#   transaction_date  debt_to_income_ratio  risk_score customer_segment
# 0       2023-06-10              0.072961       165.2      Medium Risk
# 1       2024-10-07              0.148076       266.0        High Risk
# 2       2023-04-05              0.120244       229.6        High Risk
# 3       2023-06-24              0.282653       356.0        High Risk
# 4       2024-10-19              0.116698       135.2        High Risk
# 數值欄位摘要:
#             user_id           age  monthly_income  credit_score  \
# count  10345.000000  10345.000000    10345.000000  10345.000000
# mean    5173.000000     38.559884    35053.381898    448.176124
# std     2986.488601     12.131789    27084.517277    136.518332
# min        1.000000     18.000000     5000.000000    300.000000
# 25%     2587.000000     28.000000    12207.020000    332.000000
# 50%     5173.000000     39.000000    23800.520000    403.000000
# 75%     7759.000000     49.000000    55276.930000    547.000000
# max    10345.000000     59.000000   145767.120000    850.000000
#
#        purchase_amount  bnpl_installments  repayment_delay_days  \
# count     10345.000000       10345.000000          10345.000000
# mean       3979.402721           7.477525              8.742774
# std        1500.828483           3.362867              6.781849
# min         100.000000           3.000000              0.000000
# 25%        2990.720000           3.000000              2.000000
# 50%        5000.000000           9.000000              9.000000
# 75%        5000.000000           9.000000             14.000000
# max        5000.000000          12.000000             33.000000
#
#        missed_payments  default_flag  app_usage_frequency  \
# count     10345.000000  10345.000000         10345.000000
# mean          1.015950      0.390527             5.524101
# std           0.996726      0.487892             2.590364
# min           0.000000      0.000000             1.000000
# 25%           0.000000      0.000000             3.300000
# 50%           1.000000      0.000000             5.550000
# 75%           2.000000      1.000000             7.750000
# max           7.000000      1.000000            10.000000
#
#        debt_to_income_ratio    risk_score
# count          10345.000000  10345.000000
# mean               0.181071    198.534094
# std                0.124887     67.541384
# min                0.000811      0.000000
# 25%                0.080187    153.600000
# 50%                0.138263    202.800000
# 75%                0.268300    250.800000
# max                0.723460    398.000000
# 所有欄位摘要:
#                         count unique         top  freq          mean  \
# user_id               10345.0    NaN         NaN   NaN        5173.0
# age                   10345.0    NaN         NaN   NaN     38.559884
# employment_type         10345      4    Salaried  2632           NaN
# monthly_income        10345.0    NaN         NaN   NaN  35053.381898
# credit_score          10345.0    NaN         NaN   NaN    448.176124
# purchase_amount       10345.0    NaN         NaN   NaN   3979.402721
# product_category        10345      5     Fashion  2166           NaN
# bnpl_installments     10345.0    NaN         NaN   NaN      7.477525
# repayment_delay_days  10345.0    NaN         NaN   NaN      8.742774
# missed_payments       10345.0    NaN         NaN   NaN       1.01595
# default_flag          10345.0    NaN         NaN   NaN      0.390527
# app_usage_frequency   10345.0    NaN         NaN   NaN      5.524101
# location                10345      6     Germany  1760           NaN
# transaction_date        10345    365  2024-08-15    42           NaN
# debt_to_income_ratio  10345.0    NaN         NaN   NaN      0.181071
# risk_score            10345.0    NaN         NaN   NaN    198.534094
# customer_segment        10345      3   High Risk  7569           NaN
#
#                                std       min       25%       50%       75%  \
# user_id                2986.488601       1.0    2587.0    5173.0    7759.0
# age                      12.131789      18.0      28.0      39.0      49.0
# employment_type                NaN       NaN       NaN       NaN       NaN
# monthly_income        27084.517277    5000.0  12207.02  23800.52  55276.93
# credit_score            136.518332     300.0     332.0     403.0     547.0
# purchase_amount        1500.828483     100.0   2990.72    5000.0    5000.0
# product_category               NaN       NaN       NaN       NaN       NaN
# bnpl_installments         3.362867       3.0       3.0       9.0       9.0
# repayment_delay_days      6.781849       0.0       2.0       9.0      14.0
# missed_payments           0.996726       0.0       0.0       1.0       2.0
# default_flag              0.487892       0.0       0.0       0.0       1.0
# app_usage_frequency       2.590364       1.0       3.3      5.55      7.75
# location                       NaN       NaN       NaN       NaN       NaN
# transaction_date               NaN       NaN       NaN       NaN       NaN
# debt_to_income_ratio      0.124887  0.000811  0.080187  0.138263    0.2683
# risk_score               67.541384       0.0     153.6     202.8     250.8
# customer_segment               NaN       NaN       NaN       NaN       NaN
#
#                             max
# user_id                 10345.0
# age                        59.0
# employment_type             NaN
# monthly_income        145767.12
# credit_score              850.0
# purchase_amount          5000.0
# product_category            NaN
# bnpl_installments          12.0
# repayment_delay_days       33.0
# missed_payments             7.0
# default_flag                1.0
# app_usage_frequency        10.0
# location                    NaN
# transaction_date            NaN
# debt_to_income_ratio    0.72346
# risk_score                398.0
# customer_segment            NaN

# %% [markdown]
# # NAN 與 重複資料 與 標籤雜訊

# %%
print("--- 欄位資訊 ---")
df.info()

print("\n--- 缺失值統計 ---")
display(df.isna().sum())

print(f"\n--- 重複資料筆數: {df.duplicated().sum()} ---")

# 檢查 default_flag 的唯一值
print("\n--- 標籤檢查 (default_flag) ---")
unique_values = sorted(df['default_flag'].unique())
print(f"唯一值: {unique_values}")
print(f"值的數量: {len(unique_values)}")

# 驗證是否只有 0 和 1
if set(unique_values) == {0, 1}:
    print("✅ 標籤正確：只包含 0 和 1")
else:
    print(f"⚠️ 標籤異常：包含非預期的值 {set(unique_values) - {0, 1}}")
# Out:
# --- 欄位資訊 ---
# <class 'pandas.DataFrame'>
# RangeIndex: 10345 entries, 0 to 10344
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               10345 non-null  int64
#  1   age                   10345 non-null  int64
#  2   employment_type       10345 non-null  str
#  3   monthly_income        10345 non-null  float64
#  4   credit_score          10345 non-null  int64
#  5   purchase_amount       10345 non-null  float64
#  6   product_category      10345 non-null  str
#  7   bnpl_installments     10345 non-null  int64
#  8   repayment_delay_days  10345 non-null  int64
#  9   missed_payments       10345 non-null  int64
#  10  default_flag          10345 non-null  int64
#  11  app_usage_frequency   10345 non-null  float64
#  12  location              10345 non-null  str
#  13  transaction_date      10345 non-null  str
#  14  debt_to_income_ratio  10345 non-null  float64
#  15  risk_score            10345 non-null  float64
#  16  customer_segment      10345 non-null  str
# dtypes: float64(5), int64(7), str(5)
# memory usage: 1.3 MB
#
# --- 缺失值統計 ---
# user_id                 0
# age                     0
# employment_type         0
# monthly_income          0
# credit_score            0
# purchase_amount         0
# product_category        0
# bnpl_installments       0
# repayment_delay_days    0
# missed_payments         0
# default_flag            0
# app_usage_frequency     0
# location                0
# transaction_date        0
# debt_to_income_ratio    0
# risk_score              0
# customer_segment        0
# dtype: int64
# --- 重複資料筆數: 0 ---
#
# --- 標籤檢查 (default_flag) ---
# 唯一值: [np.int64(0), np.int64(1)]
# 值的數量: 2
# ✅ 標籤正確：只包含 0 和 1

# %% [markdown]
# # 結論
# 無 NAN 與 重複 與 錯誤標籤
